# %% [markdown]
# ### Targets
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
#
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Get: Temperature, Latitude, Humidity, Cloudiness, Wind Speed

# %%
# !pip install citipy

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from scipy.stats import linregress
from citipy import citipy
from config import api_key
from pprint import pprint
import csv

# %%
def randcoord():
    randlat = random.randrange(-9000,9000,1)/100
    randlong = random.randrange(-18000,18000,1)/100
    coords = [randlat,randlong]
    return coords

# %%
g_key = 'AIzaSyD-boXPwRdVVbHB32FRptRfKV84aVgbgsg' # i know its a faux pas to store this heres

cities = []
citykey = ['']
countries = []
lats = []
longs = []
drop_count = 0

while len(cities) < 501: # need to find a way to dedupe
    coords = randcoord()
    city = citipy.nearest_city(coords[0], coords[1])
    
    city_name = city.city_name
    country_name = city.country_code
    citynatkey = city_name+country_name
    
    try:
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'locality={0}&address={0}&country=seychelles&key={2}').format(city_name,country_name, g_key)
        geo_data = requests.get(target_url).json()

        if geo_data['status'] == 'ZERO_RESULTS':
            mappable = False
        else:
            mappable = True
    except:
        mappable = False

    # Gets Country Code
    if mappable == True:
        for i in range((len(geo_data['results'][0]['address_components']))):
            if geo_data['results'][0]['address_components'][i]['types'][0] == 'country':
                country_code = geo_data['results'][0]['address_components'][i]['short_name'].lower()
    else:
        country_code = ''
        
    # Ensures API got the right city in the right country. 
    # Citipy doesn't have state/province, otherwise I'd check that too.
    if country_name == country_code:
        country_match = True
    else:
        country_match = False
        
        
    if mappable == True and country_match == True and max([i==citynatkey for i in citykey]) == False:
            
        cities.append(city.city_name)
        countries.append(country_name)
        lats.append(geo_data['results'][0]['geometry']['location']['lat'])
        longs.append(geo_data['results'][0]['geometry']['location']['lng'])
        print(f"Adding {city_name},{country_name},{geo_data['results'][0]['geometry']['location']['lat']},{geo_data['results'][0]['geometry']['location']['lng']}")
        citykey.append(citynatkey) 
    else: 
        drop_count = drop_count+1
    
city_sample = {"city":cities, "country":countries, "lat":lats, "long":longs}
print(f"For the sake of accuracy {drop_count} cities were removed from sample.")
# Out:
# Adding luanda,ao,-8.8146556,13.2301756
# Adding hobart,au,-42.8821377,147.3271949
# Adding yellowknife,ca,62.4539717,-114.3717887
# Adding los llanos de aridane,es,28.6183515,-17.8998566
# Adding barrow,us,36.0727771,-95.9195026
# Adding taolanaro,mg,-25.0225309,46.9853688
# Adding kupang,id,-10.1771997,123.6070329
# Adding ushuaia,ar,-54.8019121,-68.3029511
# Adding mahebourg,mu,-20.4059505,57.7034222
# Adding awbari,ly,26.5810176,12.7939759
# Adding rikitea,pf,-23.1223034,-134.9691543
# Adding butaritari,ki,3.1166667,172.8
# Adding mareeba,au,-17.0019368,145.4388546
# Adding torrington,us,41.8003049,-73.1211715
# Adding tongren,cn,27.731514,109.189598
# Adding mar del plata,ar,-38.0054771,-57.5426106
# Adding norman wells,ca,65.28149379999999,-126.8286524
# Adding salalah,om,17.0193843,54.11075049999999
# Adding necochea,ar,-38.5544968,-58.73960879999999
# Adding illoqqortoormiut,gl,70.48556909999999,-21.9628757
# Adding punta arenas,cl,-53.1638329,-70.9170683
# Adding nizhniy odes,ru,63.6378381,54.84651059999999
# Adding new norfolk,au,-42.7828332,147.0593848
# Adding bredasdorp,za,-34.5385222,20.0568771
# Adding mys shmidta,ru,68.8931114,-179.4125967
# Adding srednekolymsk,ru,67.43730699999999,153.728674
# Adding hermanus,za,-34.4092004,19.2504436
# Adding busselton,au,-33.6531584,115.3454892
# Adding dalbandin,pk,28.8854045,64.3963673
# Adding lompoc,us,34.6391501,-120.4579409
# Adding inhumas,br,-16.3731342,-49.4916808
# Adding saskylakh,ru,71.954308,114.1198349
# Adding atuona,pf,-9.8028605,-139.0398069
# Adding katsuura,jp,35.1522272,140.3208833
# Adding te anau,nz,-45.4144515,167.718053
# Adding clyde river,ca,70.47636500000002,-68.60126509999999
# Adding hilo,us,19.7241106,-155.0868193
# Adding olafsvik,is,64.89604849999999,-23.7060262
# Adding hofn,is,64.24970259999999,-15.2020077
# Adding baruun-urt,mn,46.6652838,113.2876804
# Adding kamyaran,ir,34.7955755,46.9368047
# Adding traverse city,us,44.7630567,-85.62063169999999
# Adding avarua,ck,-21.2129007,-159.7823059
# Adding constitucion,mx,29.9199404,-106.7960624
# Adding lalganj,in,26.1650564,80.9705292
# Adding airai,pw,7.396611799999999,134.5690225
# Adding virginia beach,us,36.8529263,-75.97798499999999
# Adding port keats,au,-14.250637,129.549659
# Adding cayenne,gf,4.92242,-52.3134531
# Adding cape town,za,-33.9248685,18.4240553
# Adding beringovskiy,ru,63.0611249,179.3485395
# For the sake of accuracy 34 cities were removed from sample.

# %%
temperatures = []
humidities = []
clouds = []
wind_speeds = []

for i in range(len(city_sample['city'])):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={city_sample['lat'][i]}&lon={city_sample['long'][i]}&appid={api_key}"
    
    try:
        print(f'Processing City {i} : {city_sample["city"][i]}, {city_sample["country"][i]}')
        
        output = requests.get(url).json()
        
    
        temp = output["main"]['temp'] # convert to fahrenheit
        humidity = output['main']['humidity'] #Percentage?
        cloudiness = output['clouds']['all'] # Percentage?
        wind = output['wind']['speed'] #mph?
        
        temp_c = temp - 273.15
        temp_f = temp_c*(9/5)+32
        
    except:
        print(f"Skipping City {i} - No data found for {city_sample['city'][i]}, {city_sample['country'][i]}")
        temp_f = 0 # convert to fahrenheit
        humidity = 0 #Percentage?
        cloudiness = 0 # Percentage?
        wind = 0 #mph?
    
    temperatures.append(temp_f)
    humidities.append(humidity)
    clouds.append(cloudiness)
    wind_speeds.append(wind)
# Out:
# Processing City 0 : luanda, ao
# Processing City 1 : hobart, au
# Processing City 2 : yellowknife, ca
# Processing City 3 : los llanos de aridane, es
# Processing City 4 : barrow, us
# Processing City 5 : taolanaro, mg
# Processing City 6 : kupang, id
# Processing City 7 : ushuaia, ar
# Processing City 8 : mahebourg, mu
# Processing City 9 : awbari, ly
# Processing City 10 : rikitea, pf
# Processing City 11 : butaritari, ki
# Processing City 12 : mareeba, au
# Processing City 13 : torrington, us
# Processing City 14 : tongren, cn
# Processing City 15 : mar del plata, ar
# Processing City 16 : norman wells, ca
# Processing City 17 : salalah, om
# Processing City 18 : necochea, ar
# Processing City 19 : illoqqortoormiut, gl
# Processing City 20 : punta arenas, cl
# Processing City 21 : nizhniy odes, ru
# Processing City 22 : new norfolk, au
# Processing City 23 : bredasdorp, za
# Processing City 24 : mys shmidta, ru
# Processing City 25 : srednekolymsk, ru
# Processing City 26 : hermanus, za
# Processing City 27 : busselton, au
# Processing City 28 : dalbandin, pk
# Processing City 29 : lompoc, us
# Processing City 30 : inhumas, br
# Processing City 31 : saskylakh, ru
# Processing City 32 : atuona, pf
# Processing City 33 : katsuura, jp
# Processing City 34 : te anau, nz
# Processing City 35 : clyde river, ca
# Processing City 36 : hilo, us
# Processing City 37 : olafsvik, is
# Processing City 38 : hofn, is
# Processing City 39 : baruun-urt, mn
# Processing City 40 : kamyaran, ir
# Processing City 41 : traverse city, us
# Processing City 42 : avarua, ck
# Processing City 43 : constitucion, mx
# Processing City 44 : lalganj, in
# Processing City 45 : airai, pw
# Processing City 46 : virginia beach, us
# Processing City 47 : port keats, au
# Processing City 48 : cayenne, gf
# Processing City 49 : cape town, za
# Processing City 50 : beringovskiy, ru

# %%
city_sample['temperature'] = temperatures
city_sample['humidity'] = humidities
city_sample['cloudiness'] =  clouds
city_sample['wind speed'] = wind_speeds

# %%
city_data = pd.DataFrame(city_sample) # output me
city_data.to_csv('city_weather_data.csv')

# %%
def regressplot(sample,dependent_variable,hemispherical = False):
    if hemispherical == False:
        xx = sample['lat']
        yy = sample[dependent_variable]
        
        (slope,intercept,rval,pval,stderr) = linregress(xx,yy)
        y_out = xx*slope + intercept
        equation = f'y = {slope}x + {intercept}'
        
       
        plt.scatter(xx,yy,alpha=.5)
        plt.plot(xx,y_out,color = 'teal', alpha = .6)
        
        plt.title(f'latitude vs. {dependent_variable}')
        plt.ylabel(f'{dependent_variable}')
        plt.xlabel('latitude (degrees)')
        
        print(f'''
        Equation : {equation}
        R-Squared : {rval**2}
        P-Value : {pval}
        ''')
        
    else:
        
        # North Hemisphere
        north = sample.loc[sample['lat'] >= 0]
        south = sample.loc[sample['lat'] < 0]
        ymin = sample[dependent_variable].min()
        ymax = sample[dependent_variable].max()
        
        x_north = north['lat']
        y_north = north[dependent_variable]
        
        x_south = south['lat']
        y_south = south[dependent_variable]
        
        # Northern Hemisphere
        (slope_north,intercept_north,rval_north,pval_north,stderr_north) = linregress(x_north,y_north)
        y_out_north = x_north*slope_north + intercept_north
        equation_north = f'y = {slope_north}x + {intercept_north}'
        
        # Southern Hemisphere
        (slope_south,intercept_south,rval_south,pval_south,stderr_south) = linregress(x_south,y_south)
        y_out_south = x_south*slope_south + intercept_south
        equation_south = f'y = {slope_south}x + {intercept_south}'

        #create plots
        plt.subplot(1, 2, 2)
        plt.scatter(x_north,y_out_north,alpha=.3)
        plt.plot(x_north,y_out_north,color = 'red', alpha = .6)
        
        plt.ylim(ymin,ymax)
        plt.ylabel(f'{dependent_variable}')
        plt.title(f'Northern Hemisphere')
        plt.xlabel('latitude (degrees)')
        
        plt.subplot(1, 2, 1)
        plt.scatter(x_south,y_out_south,alpha=.3)   
        plt.plot(x_south,y_out_south,color = 'red', alpha = .6)
        
        plt.ylim(ymin,ymax)
        plt.title(f'Southern Hemisphere')
        plt.xlabel('latitude (degrees)')
        
        print(f'''
        Northern Heisphere:
        Equation : {equation_north}
        R-Squared : {rval_north**2}
        P-Value : {pval_north}
        
        Southern Hemisphere:
        Equation : {equation_south}
        R-Squared : {rval_south**2}
        P-Value : {pval_south}
        ''')

# %%
regressplot(city_data,'temperature')
plt.savefig('Images/LatVsTemperature.png')
# Out:
#         Equation : y = 0.07096985740289707x + 60.9894287441858
#         R-Squared : 0.033351123682259176
#         P-Value : 0.1996062320178919

# %%
regressplot(city_data,'humidity')
plt.savefig('Images/LatVsHumidity.png')
# Out:
#         Equation : y = -0.0959367379238285x + 73.79388652037328
#         R-Squared : 0.05084008770566796
#         P-Value : 0.11163791991684051

# %%
regressplot(city_data,'cloudiness')
plt.savefig('Images/LatVsCloudiness.png')
# Out:
#         Equation : y = -0.06740403262894712x + 60.286131391051136
#         R-Squared : 0.007687499929194751
#         P-Value : 0.05006406172453233

# %%
regressplot(city_data,'wind speed')
plt.savefig('Images/LatVsWindspeed.png')
# Out:
#         Equation : y = -0.02471886390761667x + 6.026256841070935
#         R-Squared : 0.10901238963425716
#         P-Value : 3.5122287473678565e-14

# %%
regressplot(city_data,'temperature',hemispherical=True)
plt.savefig('Images/LatVsTemperatureByHemisphere.png')
# Out:
#         Northern Heisphere:
#         Equation : y = -0.619765150924016x + 89.69798752808975
#         R-Squared : 0.6671696835238266
#         P-Value : 4.6780915100060613e-64
#
#         Southern Hemisphere:
#         Equation : y = 1.605398326784327x + 105.24328301270748
#         R-Squared : 0.8450650460514348
#         P-Value : 1.5448100568735227e-97

# %%
regressplot(city_data,'humidity',hemispherical=True)
plt.savefig('Images/LatVsHumidityByHemisphere.png')
# Out:
#         Northern Heisphere:
#         Equation : y = 0.17995055819263958x + 67.41407871568626
#         R-Squared : 0.04465419296465275
#         P-Value : 0.0005752024317091226
#
#         Southern Hemisphere:
#         Equation : y = -0.06952350347555004x + 73.5680316239349
#         R-Squared : 0.015736379756105194
#         P-Value : 0.05327075879528392

# %%
regressplot(city_data,'cloudiness',hemispherical=True)
plt.savefig('Images/LatVsCloudinessByHemisphere.png')
# Out:
#         Northern Heisphere:
#         Equation : y = 0.17264841784559226x + 49.07889225031158
#         R-Squared : 0.010602269575951838
#         P-Value : 0.11621970485020766
#
#         Southern Hemisphere:
#         Equation : y = -0.5783205481608653x + 37.7662233162939
#         R-Squared : 0.12874253871048383
#         P-Value : 1.6779502475676062e-09

# %%
regressplot(city_data,'wind speed',hemispherical=True)
plt.savefig('Images/LatVsWindspeedByHemisphere.png')
# Out:
#         Northern Heisphere:
#         Equation : y = -0.025048663797137178x + 5.887236892662149
#         R-Squared : 0.04479482058141386
#         P-Value : 0.0005635241545778128
#
#         Southern Hemisphere:
#         Equation : y = 0.0007828106537906985x + 7.384113602415085
#         R-Squared : 1.9767430419120646e-05
#         P-Value : 0.9456028174127756
